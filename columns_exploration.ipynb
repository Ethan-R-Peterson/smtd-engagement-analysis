# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("Filemaker_CLEAN.csv")

# %%
# major_department: duplicate names, many majors. 

counts = df["participant_major_department_unique"].value_counts()
filtered = counts[counts > 1000]

print(len(filtered))
print(filtered)
# Out:
# 27
# participant_major_department_unique
# Composition                                              18501
# Winds & Percussion                                       18088
# Strings                                                  15512
# Piano                                                    12719
# Theatre & Drama                                          10394
# Voice                                                     5904
# Dance                                                     5883
# Chamber MusicWinds & Percussion                          3569
# Performing Arts Technology                                3332
# Theatre & DramaTheatre & Drama                           3316
# DanceTheatre & DramaEntrepreneurship & Leadership       2719
# Jazz                                                      2685
# Conducting                                                2387
# Music, Theatre & Dance                                    2187
# Winds & PercussionMusic, Theatre & Dance                 2157
# Theatre & DramaEntrepreneurship & LeadershipStrings     1915
# Musical Theatre                                           1818
# Winds & PercussionChamber Music                          1722
# Music, Theatre & DanceMusic, Theatre & Dance             1383
# VoiceVoice                                               1300
# Winds & PercussionWinds & Percussion                     1263
# JazzJazzMusic EducationStrings                         1248
# Ross School of Business                                   1208
# Music EducationWinds & Percussion                        1090
# Music Education                                           1067
# LSA                                                       1057
# CompositionComposition                                   1006
# Name: count, dtype: int64

# %%
# major_department: duplicate names, many majors. 
counts = df["major_department"].value_counts()
filtered = counts[counts > 1000]

print(len(filtered))
print(filtered)
# Out:
# 26
# major_department
# Composition                                                  17407
# Winds & Percussion                                           17063
# Strings                                                      15245
# Piano                                                        12173
# Music, Theatre & DanceKinesiology                           11341
# Theatre & Drama                                               9512
# Voice                                                         6075
# Dance                                                         5829
# Chamber MusicWinds & Percussion                              3522
# Performing Arts Technology                                    2977
# DanceTheatre & DramaEntrepreneurship & Leadership           2719
# Jazz                                                          2614
# Marsal Family School of EducMarsal Family School of Educ     2459
# Conducting                                                    2345
# CompositionComposition                                       2222
# Musical Theatre                                               1909
# Theatre & DramaEntrepreneurship & LeadershipStrings         1908
# Music, Theatre & Dance                                        1903
# Winds & PercussionMusic, Theatre & Dance                     1842
# Theatre & DramaTheatre & Drama                               1695
# Winds & PercussionChamber Music                              1636
# JazzJazzMusic EducationStrings                             1248
# VoiceVoice                                                   1182
# Ross School of Business                                       1110
# Music EducationWinds & Percussion                            1082
# Music Education                                               1070
# Name: count, dtype: int64

# %%
# Experience Type

print(df["experience_type"].value_counts())
# Out:
# experience_type
# Event                     93803
# Counseling Appointment    35710
# Course                    33738
# Funding                   18041
# Name: count, dtype: int64

# %%
print(df["participant_experience_type_unique"].value_counts())
# Out:
# participant_experience_type_unique
# Event                     94250
# Counseling Appointment    36079
# Course                    32800
# Funding                   18163
# Name: count, dtype: int64
