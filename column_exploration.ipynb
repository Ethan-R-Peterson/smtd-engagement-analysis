# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("Filemaker_CLEAN.csv")

# %%
# major_department: duplicate names, many majors. 

counts = df["experience_type"].value_counts()
filtered = counts[counts > 0]

print(len(filtered))
print(filtered)
# Out:
# 4
# experience_type
# Event                     78447
# Counseling Appointment    33945
# Course                    32140
# Funding                   13084
# Name: count, dtype: int64

# %%
# major_department: duplicate names, many majors. 
pd.set_option('display.max_rows', None)
counts = df["major_department"].value_counts()
filtered = counts[counts > 50]

print(len(filtered))
print(filtered)
# Out:
# 39
# major_department
# Winds & Percussion                              21130
# Composition                                     18036
# Theatre & Drama                                 17113
# Music, Theatre & Dance                          16726
# Strings                                         16635
# Piano                                           11796
# Dance                                            9203
# Voice                                            8127
# Jazz                                             6077
# Chamber Music                                    4563
# Music Education                                  3634
# Performing Arts Technology                       3628
# Conducting                                       2832
# Musicology                                       2125
# Musical Theatre                                  1992
# LSA                                              1575
# Ross School of Business                          1543
# Communication and Media                          1180
# Music                                             960
# Entrepreneurship & Leadership                     841
# Education                                         809
# Biopsych, Cognit & Neurosci                       808
# Information                                       780
# Computer Science                                  770
# Organ                                             764
# Psychology                                        477
# Political Science                                 451
# Economics                                         397
# Film, Television, and Media                       369
# Stamps School of Art & Design                     233
# Marsal Family School of Educ                      178
# Communication                                     148
# Kinesiology                                        95
# Computer Engineering                               94
# Mechanical Engineering                             75
# Arts and IdeasLiterature, Sci, and the Arts       68
# Literature, Sci, and the Arts                      64
# International Studies                              62
# Chemical Engineering                               61
# Name: count, dtype: int64

# %%
# Experience Type

print(df["experience_type"].value_counts())
# Out:
# experience_type
# Event                     78447
# Counseling Appointment    33945
# Course                    32140
# Funding                   13084
# Name: count, dtype: int64

# %%
print(df["participant_experience_type_unique"].value_counts())
# Out:
# participant_experience_type_unique
# Event                     81081
# Counseling Appointment    31792
# Course                    29528
# Funding                   15215
# Name: count, dtype: int64
